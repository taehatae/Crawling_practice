# %% [markdown]
# KNU SentiLex,KOSAC(한문 감성분석), Emolex(영문 감성분석)
# 교수님은 KNU SentiLex 사용

# %%
# 데이터프레임에 감성분석 score 삽입
import json
from tqdm import tqdm

# 감성분석 json 데이터 (KNU감성사전) 불러오기
with open(file_path + '사전경로', encoding = 'UTF-8') as json_file

# 각 문서의 평균 감성 score 반환 # 리스트의 평균 값을 계산하는 함수

# 감성사전에 있는 단어와 현재 문서의 단어 비교

# 데이터프레임에 감성분석 결과 삽입

# %%
# 토픽별 평균 score에 따른 감성 클래스 구분
# 토픽별 평균 score 0.3 초과 : 긍정
# 토픽별 평균 score -0.3 이상 0.3 이하 : 중립
# 토픽별 평균 score -0.3 미만 : 부정

# %%
# 감성 클래스별 비율 계산

# 토픽별 감성 비율 데이터프레임 생성

# 시각화

# 토픽별 감성 빈도 데이터프레임 생성

# 시각화
